# %% [markdown]
# ## Problem Statement

# %% [raw]
# We are working on Income Prediction problem associated with the Adult Income Census dataset.
# The goal is to accurately predict whether or not person is making more or less than $50,000 a year.
# While working through this problem statment.

# %% [markdown]
# #### About the Dataset
# - **Age:** Describes the age of individuals. Continuous.
# - **Workclass:** Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - **fnlwgt:** Continuous.
# - **education:** Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - **education-num:** Number of years spent in education. Continuous.
# - **marital-status:** Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - **occupation:** Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - **relationship:** Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - **race:** White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - **sex:** Female, Male.
# - **capital-gain:** Continuous.
# - **capital-loss:** Continuous.
# - **hours-per-week:** Continuous.
# - **native-country:** United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - **salary:** >50K,<=50K

# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
sns.set(rc={"figure.figsize":(15,6)})
pd.pandas.set_option("display.max_columns",None)

# %%
data = pd.read_csv("adult.csv")

# %%
data.head() # capital.loss = rename(capital_loss)
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# Check null values in our complete dataset
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
# check duplicet value in data set
data.duplicated().sum()
# Out:
# 24

# %%
# drop duplicate value from data
data.drop_duplicates(inplace=True)

# %%
data.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32537.000000  3.253700e+04   32537.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05      10.081815   1078.443741     87.368227
# std       13.637984  1.055565e+05       2.571633   7387.957424    403.101833
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# saprate catigorical and numerical features
catigorical_features = data.select_dtypes(include="object").columns
numerical_features = data.select_dtypes(exclude="object").columns

# %%
catigorical_features
# Out:
# Index(['workclass', 'education', 'marital.status', 'occupation',
#        'relationship', 'race', 'sex', 'native.country', 'income'],
#       dtype='object')

# %%
numerical_features
# Out:
# Index(['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss',
#        'hours.per.week'],
#       dtype='object')

# %%
data['workclass'].value_counts()
# Out:
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
# fetch the unique value from catigorical data
for i in catigorical_features:
    print(i,data[i].unique())
    
    print()
    print("*****************************Seperated_Columns********************************")
    print()
# Out:
# workclass ['?' 'Private' 'State-gov' 'Federal-gov' 'Self-emp-not-inc' 'Self-emp-inc'
#  'Local-gov' 'Without-pay' 'Never-worked']
#
# *****************************Seperated_Columns********************************
#
# education ['HS-grad' 'Some-college' '7th-8th' '10th' 'Doctorate' 'Prof-school'
#  'Bachelors' 'Masters' '11th' 'Assoc-acdm' 'Assoc-voc' '1st-4th' '5th-6th'
#  '12th' '9th' 'Preschool']
#
# *****************************Seperated_Columns********************************
#
# marital.status ['Widowed' 'Divorced' 'Separated' 'Never-married' 'Married-civ-spouse'
#  'Married-spouse-absent' 'Married-AF-spouse']
#
# *****************************Seperated_Columns********************************
#
# occupation ['?' 'Exec-managerial' 'Machine-op-inspct' 'Prof-specialty'
#  'Other-service' 'Adm-clerical' 'Craft-repair' 'Transport-moving'
#  'Handlers-cleaners' 'Sales' 'Farming-fishing' 'Tech-support'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
#
# *****************************Seperated_Columns********************************
#
# relationship ['Not-in-family' 'Unmarried' 'Own-child' 'Other-relative' 'Husband' 'Wife']
#
# *****************************Seperated_Columns********************************
#
# race ['White' 'Black' 'Asian-Pac-Islander' 'Other' 'Amer-Indian-Eskimo']
#
# *****************************Seperated_Columns********************************
#
# sex ['Female' 'Male']
#
# *****************************Seperated_Columns********************************
#
# native.country ['United-States' '?' 'Mexico' 'Greece' 'Vietnam' 'China' 'Taiwan' 'India'
#  'Philippines' 'Trinadad&Tobago' 'Canada' 'South' 'Holand-Netherlands'
#  'Puerto-Rico' 'Poland' 'Iran' 'England' 'Germany' 'Italy' 'Japan' 'Hong'
#  'Honduras' 'Cuba' 'Ireland' 'Cambodia' 'Peru' 'Nicaragua'
#  'Dominican-Republic' 'Haiti' 'El-Salvador' 'Hungary' 'Columbia'
#  'Guatemala' 'Jamaica' 'Ecuador' 'France' 'Yugoslavia' 'Scotland'
#  'Portugal' 'Laos' 'Thailand' 'Outlying-US(Guam-USVI-etc)']
#
# *****************************Seperated_Columns********************************
#
# income ['<=50K' '>50K']
#
# *****************************Seperated_Columns********************************

# %%
# remove ? and replace with mode value # .mode()
data["workclass"] = data["workclass"].replace(" ?"," Private")
data["occupation"] = data["occupation"].replace(" ?"," Prof-specialty")
data["native_country"] = data["native.country"].replace(" ?"," United-States")

# %% [markdown]
# # Data Visualization

# %%
plt.style.use('fivethirtyeight')
sns.set(rc={"figure.figsize":(15,6)})

colmns1 = ['workclass', 'education', 'marital.status', 'occupation']

for i in range(0,len(colmns1)):
    plt.subplot(2,4,i+1)
    sns.countplot(x=data[colmns1[i]])
    plt.xticks(size=15,rotation=90)
    plt.tight_layout()

# %%
colmns2 = ['relationship', 'race', 'sex', 'income']

for i in range(0,len(colmns2)):
    plt.subplot(2,4,i+1)
    sns.countplot(x=data[colmns2[i]])
    plt.xticks(size=15,rotation=90)
    plt.tight_layout()

# %%
plt.suptitle("Distribution Graphs of numerical features")
for i in range(0,len(numerical_features)):
    plt.subplot(2,4,i+1)
    sns.distplot(x=data[numerical_features[i]])
    plt.xticks(size=15,rotation=90)
    plt.tight_layout()

# %%
plt.suptitle("Boxplot of numerical features to see outlayers ")
for i in range(0,len(numerical_features)):
    plt.subplot(2,4,i+1)
    sns.boxplot(x=data[numerical_features[i]])
    plt.xticks(size=15,rotation=90)
    plt.tight_layout()

# %%
data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income native_country
# 0          4356              40  United-States  <=50K  United-States
# 1          4356              18  United-States  <=50K  United-States
# 2          4356              40  United-States  <=50K  United-States
# 3          3900              40  United-States  <=50K  United-States
# 4          3900              40  United-States  <=50K  United-States

# %%
salary = pd.crosstab(data['income'],data['workclass'])
salary.plot(kind='bar')
# Out:
# <Axes: xlabel='income'>

# %%
education = pd.crosstab(data['income'],data['education'])
education.plot(kind="bar")
# Out:
# <Axes: xlabel='income'>

# %%
marital_status = pd.crosstab(data['income'],data['marital.status'])
marital_status.plot(kind="bar")
# Out:
# <Axes: xlabel='income'>

# %%
occupation = pd.crosstab(data['income'],data['occupation'])
occupation.plot(kind="bar")
# Out:
# <Axes: xlabel='income'>

# %%
relationship = pd.crosstab(data['income'],data['relationship'])
relationship.plot(kind="bar")
# Out:
# <Axes: xlabel='income'>

# %%
sex = pd.crosstab(data['income'],data['sex'])
sex.plot(kind="bar")
# Out:
# <Axes: xlabel='income'>

# %%
catigorical_features
# Out:
# Index(['workclass', 'education', 'marital.status', 'occupation',
#        'relationship', 'race', 'sex', 'native.country', 'income'],
#       dtype='object')

# %%
data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income native_country
# 0          4356              40  United-States  <=50K  United-States
# 1          4356              18  United-States  <=50K  United-States
# 2          4356              40  United-States  <=50K  United-States
# 3          3900              40  United-States  <=50K  United-States
# 4          3900              40  United-States  <=50K  United-States

# %%
from sklearn.preprocessing import LabelEncoder

# create a LabelEncoder object
le = LabelEncoder()

# define the categorical features
categorical_features =['workclass', 'education', 'marital.status', 'occupation',
       'relationship', 'race', 'sex', 'native_country']

# loop through the categorical features and encode them
for feature in categorical_features:
    le.fit(data[feature])
    data[feature] = le.transform(data[feature])

# %%
data = data.drop('native.country', axis=1)

# %%
data['income']
# Out:
# 0        <=50K
# 1        <=50K
# 2        <=50K
# 3        <=50K
# 4        <=50K
#          ...
# 32556    <=50K
# 32557    <=50K
# 32558     >50K
# 32559    <=50K
# 32560    <=50K
# Name: income, Length: 32537, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['income'] = le.fit_transform(data['income'])

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'income',
#        'native_country'],
#       dtype='object')

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   90          0   77053         11              9               6
# 1   82          4  132870         11              9               6
# 2   66          0  186061         15             10               6
# 3   54          4  140359          5              4               0
# 4   41          4  264663         15             10               5
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           0             1     4    0             0          4356
# 1           4             1     4    0             0          4356
# 2           0             4     2    0             0          4356
# 3           7             4     4    0             0          3900
# 4          10             3     4    0             0          3900
#
#    hours.per.week  income  native_country
# 0              40       0              39
# 1              18       0              39
# 2              40       0              39
# 3              40       0              39
# 4              40       0              39

# %%
data['income'].value_counts()
# Out:
# income
# 0    24698
# 1     7839
# Name: count, dtype: int64

# %%
# droping education_num column because we have education ordinal encorded one
data.drop(["education","fnlwgt"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    age  workclass  education.num  marital.status  occupation  relationship  \
# 0   90          0              9               6           0             1
# 1   82          4              9               6           4             1
# 2   66          0             10               6           0             4
# 3   54          4              4               0           7             4
# 4   41          4             10               5          10             3
#
#    race  sex  capital.gain  capital.loss  hours.per.week  income  \
# 0     4    0             0          4356              40       0
# 1     4    0             0          4356              18       0
# 2     2    0             0          4356              40       0
# 3     4    0             0          3900              40       0
# 4     4    0             0          3900              40       0
#
#    native_country
# 0              39
# 1              39
# 2              39
# 3              39
# 4              39

# %%
data.to_csv("cleandata.csv",index=False)

# %% [markdown]
# ## Model Traning

# %%
data.shape
# Out:
# (32537, 13)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education.num', 'marital.status', 'occupation',
#        'relationship', 'race', 'sex', 'capital.gain', 'capital.loss',
#        'hours.per.week', 'income', 'native_country'],
#       dtype='object')

# %%
# Saprate dependent and indipendent features
x = data.drop("income",axis=1)
y = data["income"]

# %%
catigorical_features = x.select_dtypes(include="object").columns
numerical_features = x.select_dtypes(exclude="object").columns
print(catigorical_features)
print(numerical_features)
# Out:
# Index([], dtype='object')
# Index(['age', 'workclass', 'education.num', 'marital.status', 'occupation',
#        'relationship', 'race', 'sex', 'capital.gain', 'capital.loss',
#        'hours.per.week', 'native_country'],
#       dtype='object')

# %%
# ( age, workclass, education_num, marital_status, occupation,relationship,  race,sex,  capital_gain, capital_loss,
#  hours_per_week, native_country)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[189], line 1
# ----> 1 ( age, workclass, education_num, marital_status, occupation,relationship,  race,sex,  capital_gain, capital_loss,
#       2  hours_per_week, native_country)
#
# NameError: name 'age' is not defined

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
#pipline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
num_pipline = Pipeline(
    steps=[
        ("imputer",SimpleImputer(strategy="median")),
        ("scaler",StandardScaler())
    ]

) # to standardize the data values into a standard format.

cato_pipline = Pipeline(
    steps=[
        ("imputer",SimpleImputer(strategy="most_frequent")),
        ("scaler",StandardScaler())
    ]

)

# apply transform to particular columns. 
preprocessor = ColumnTransformer([
    ("num_pipline",num_pipline,numerical_features)
])

# %%
# Train test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (26029, 12)
# (6508, 12)
# (26029,)
# (6508,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score,classification_report,ConfusionMatrixDisplay

# %%
def performance_metrices(test,predict):
    confusionmetrix = print(f"CONFUSION_METRIX: {confusion_matrix(test,predict)}")
    
    precision = print(f"PRECISION_SCORE: {precision_score(test,predict)}")
    
    recall = print(f"RECALL_SCORE: {recall_score(test,predict)}")
    
    f1score = print(f"F1_SCORE: {f1_score(test,predict)}")
    
    accuracyscore = print(f"ACCURACY_SCORE: {accuracy_score(test,predict)}")
    
    return confusionmetrix,precision,recall,f1score,accuracyscore

# %% [markdown]
# ## Use Hyperparemetertuning

# %%
lr = LogisticRegression()

# %%
pram = {
    "class_weight":["balanced"],
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga']
    
}

# %%
grid = GridSearchCV(estimator=lr,param_grid=pram,cv=5,n_jobs=-1, verbose=3)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END C=0.001, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.726 total time=   0.2s
# [CV 2/5] END C=0.001, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.728 total time=   0.2s
# [CV 3/5] END C=0.001, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.735 total time=   0.2s
# [CV 5/5] END C=0.001, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.739 total time=   0.3s
# [CV 4/5] END C=0.001, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.733 total time=   0.3s
# [CV 2/5] END C=0.001, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.734 total time=   0.3s
# [CV 1/5] END C=0.001, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.729 total time=   0.3s
# [CV 3/5] END C=0.001, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.736 total time=   0.3s
# [CV 4/5] END C=0.001, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.728 total time=   0.2s
# [CV 5/5] END C=0.001, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.740 total time=   0.3s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 4/5] END C=0.001, class_weight=balanced, penalty=l1, solver=saga;, score=0.774 total time=   1.3s
# [CV 2/5] END C=0.001, class_weight=balanced, penalty=l1, solver=saga;, score=0.776 total time=   1.7s
# [CV 3/5] END C=0.001, class_weight=balanced, penalty=l1, solver=saga;, score=0.781 total time=   1.7s
# [CV 5/5] END C=0.001, class_weight=balanced, penalty=l1, solver=saga;, score=0.782 total time=   1.5s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/5] END C=0.001, class_weight=balanced, penalty=l2, solver=saga;, score=0.784 total time=   1.2s
# [CV 1/5] END C=0.001, class_weight=balanced, penalty=l1, solver=saga;, score=0.784 total time=   2.0s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END C=0.001, class_weight=balanced, penalty=l2, solver=saga;, score=0.776 total time=   1.3s
# [CV 3/5] END C=0.001, class_weight=balanced, penalty=l2, solver=saga;, score=0.781 total time=   1.4s
# [CV 2/5] END C=0.01, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.752 total time=   0.4s
# [CV 1/5] END C=0.01, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.754 total time=   0.6s
# [CV 3/5] END C=0.01, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.765 total time=   0.5s
# [CV 4/5] END C=0.01, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.756 total time=   0.4s
# [CV 5/5] END C=0.01, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.760 total time=   0.5s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 4/5] END C=0.001, class_weight=balanced, penalty=l2, solver=saga;, score=0.774 total time=   1.6s
# [CV 5/5] END C=0.001, class_weight=balanced, penalty=l2, solver=saga;, score=0.782 total time=   1.5s
# [CV 1/5] END C=0.01, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.738 total time=   0.5s
# [CV 2/5] END C=0.01, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.730 total time=   0.3s
# [CV 3/5] END C=0.01, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.737 total time=   0.3s
# [CV 4/5] END C=0.01, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.726 total time=   0.3s
# [CV 5/5] END C=0.01, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.739 total time=   0.3s
# [CV 4/5] END C=0.01, class_weight=balanced, penalty=l1, solver=saga;, score=0.774 total time=   1.4s
# [CV 1/5] END C=0.01, class_weight=balanced, penalty=l1, solver=saga;, score=0.784 total time=   1.5s
# [CV 3/5] END C=0.01, class_weight=balanced, penalty=l1, solver=saga;, score=0.781 total time=   1.5s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END C=0.01, class_weight=balanced, penalty=l1, solver=saga;, score=0.776 total time=   1.6s
# [CV 5/5] END C=0.01, class_weight=balanced, penalty=l1, solver=saga;, score=0.782 total time=   1.5s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/5] END C=0.1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.760 total time=   0.4s
# [CV 2/5] END C=0.1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.765 total time=   0.3s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 3/5] END C=0.1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.779 total time=   0.5s
# [CV 1/5] END C=0.01, class_weight=balanced, penalty=l2, solver=saga;, score=0.784 total time=   1.1s
# [CV 5/5] END C=0.1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.769 total time=   0.4s
# [CV 4/5] END C=0.1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.770 total time=   0.5s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 3/5] END C=0.01, class_weight=balanced, penalty=l2, solver=saga;, score=0.781 total time=   1.1s
# [CV 4/5] END C=0.01, class_weight=balanced, penalty=l2, solver=saga;, score=0.774 total time=   1.1s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END C=0.01, class_weight=balanced, penalty=l2, solver=saga;, score=0.776 total time=   1.4s
# [CV 5/5] END C=0.01, class_weight=balanced, penalty=l2, solver=saga;, score=0.782 total time=   1.3s
# [CV 1/5] END C=0.1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.726 total time=   0.3s
# [CV 3/5] END C=0.1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.737 total time=   0.3s
# [CV 4/5] END C=0.1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.726 total time=   0.3s
# [CV 2/5] END C=0.1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.734 total time=   0.4s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END C=0.1, class_weight=balanced, penalty=l1, solver=saga;, score=0.776 total time=   1.3s
# [CV 5/5] END C=0.1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.768 total time=   0.5s
# [CV 1/5] END C=0.1, class_weight=balanced, penalty=l1, solver=saga;, score=0.784 total time=   1.4s
# [CV 3/5] END C=0.1, class_weight=balanced, penalty=l1, solver=saga;, score=0.781 total time=   1.3s
# [CV 4/5] END C=0.1, class_weight=balanced, penalty=l1, solver=saga;, score=0.774 total time=   1.3s
# [CV 5/5] END C=0.1, class_weight=balanced, penalty=l1, solver=saga;, score=0.782 total time=   1.3s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/5] END C=0.1, class_weight=balanced, penalty=l2, solver=saga;, score=0.784 total time=   1.0s
# [CV 2/5] END C=1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.766 total time=   0.5s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END C=0.1, class_weight=balanced, penalty=l2, solver=saga;, score=0.776 total time=   1.1s
# [CV 3/5] END C=1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.780 total time=   0.6s
# [CV 1/5] END C=1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.766 total time=   0.8s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 4/5] END C=0.1, class_weight=balanced, penalty=l2, solver=saga;, score=0.774 total time=   1.3s
# [CV 5/5] END C=1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.770 total time=   0.6s
# [CV 5/5] END C=0.1, class_weight=balanced, penalty=l2, solver=saga;, score=0.782 total time=   1.3s
# [CV 4/5] END C=1, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.771 total time=   0.8s
# [CV 3/5] END C=0.1, class_weight=balanced, penalty=l2, solver=saga;, score=0.781 total time=   1.5s
# [CV 2/5] END C=1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.730 total time=   0.3s
# [CV 1/5] END C=1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.730 total time=   0.3s
# [CV 3/5] END C=1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.777 total time=   0.5s
# [CV 4/5] END C=1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.731 total time=   0.3s
# [CV 5/5] END C=1, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.741 total time=   0.3s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/5] END C=1, class_weight=balanced, penalty=l1, solver=saga;, score=0.784 total time=   1.4s
# [CV 2/5] END C=1, class_weight=balanced, penalty=l1, solver=saga;, score=0.776 total time=   1.4s
# [CV 3/5] END C=1, class_weight=balanced, penalty=l1, solver=saga;, score=0.781 total time=   1.2s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 4/5] END C=1, class_weight=balanced, penalty=l1, solver=saga;, score=0.774 total time=   1.2s
# [CV 5/5] END C=1, class_weight=balanced, penalty=l1, solver=saga;, score=0.782 total time=   1.2s
# [CV 1/5] END C=10, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.762 total time=   0.3s
# [CV 1/5] END C=1, class_weight=balanced, penalty=l2, solver=saga;, score=0.784 total time=   0.9s
# [CV 3/5] END C=10, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.778 total time=   0.3s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END C=1, class_weight=balanced, penalty=l2, solver=saga;, score=0.776 total time=   1.0s
# [CV 2/5] END C=10, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.768 total time=   0.5s
# [CV 4/5] END C=1, class_weight=balanced, penalty=l2, solver=saga;, score=0.774 total time=   0.9s
# [CV 3/5] END C=1, class_weight=balanced, penalty=l2, solver=saga;, score=0.781 total time=   1.0s
# [CV 4/5] END C=10, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.770 total time=   0.4s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 5/5] END C=1, class_weight=balanced, penalty=l2, solver=saga;, score=0.782 total time=   1.1s
# [CV 1/5] END C=10, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.726 total time=   0.3s
# [CV 5/5] END C=10, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.771 total time=   0.6s
# [CV 3/5] END C=10, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.737 total time=   0.3s
# [CV 2/5] END C=10, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.743 total time=   0.5s
# [CV 4/5] END C=10, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.727 total time=   0.3s
# [CV 5/5] END C=10, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.739 total time=   0.3s
# [CV 1/5] END C=10, class_weight=balanced, penalty=l1, solver=saga;, score=0.784 total time=   1.3s
# [CV 2/5] END C=10, class_weight=balanced, penalty=l1, solver=saga;, score=0.776 total time=   1.2s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 5/5] END C=10, class_weight=balanced, penalty=l1, solver=saga;, score=0.782 total time=   1.2s
# [CV 4/5] END C=10, class_weight=balanced, penalty=l1, solver=saga;, score=0.774 total time=   1.3s
# [CV 3/5] END C=10, class_weight=balanced, penalty=l1, solver=saga;, score=0.781 total time=   1.3s
# [CV 1/5] END C=100, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.762 total time=   0.4s
# [CV 2/5] END C=10, class_weight=balanced, penalty=l2, solver=saga;, score=0.776 total time=   1.0s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/5] END C=10, class_weight=balanced, penalty=l2, solver=saga;, score=0.784 total time=   1.1s
# [CV 2/5] END C=100, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.768 total time=   0.6s
# [CV 3/5] END C=100, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.780 total time=   0.6s
# [CV 3/5] END C=10, class_weight=balanced, penalty=l2, solver=saga;, score=0.781 total time=   1.0s
# [CV 4/5] END C=100, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.770 total time=   0.4s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 5/5] END C=100, class_weight=balanced, penalty=l1, solver=liblinear;, score=0.769 total time=   0.3s
# [CV 5/5] END C=10, class_weight=balanced, penalty=l2, solver=saga;, score=0.782 total time=   1.1s
# [CV 4/5] END C=10, class_weight=balanced, penalty=l2, solver=saga;, score=0.774 total time=   1.2s
# [CV 2/5] END C=100, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.737 total time=   0.5s
# [CV 3/5] END C=100, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.747 total time=   0.5s
# [CV 1/5] END C=100, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.759 total time=   0.6s
# [CV 5/5] END C=100, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.744 total time=   0.4s
# [CV 1/5] END C=100, class_weight=balanced, penalty=l1, solver=saga;, score=0.784 total time=   1.4s
# [CV 2/5] END C=100, class_weight=balanced, penalty=l1, solver=saga;, score=0.776 total time=   1.4s
# [CV 3/5] END C=100, class_weight=balanced, penalty=l1, solver=saga;, score=0.781 total time=   1.4s
# [CV 4/5] END C=100, class_weight=balanced, penalty=l2, solver=liblinear;, score=0.768 total time=   0.6s
# [CV 4/5] END C=100, class_weight=balanced, penalty=l1, solver=saga;, score=0.774 total time=   1.4s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 5/5] END C=100, class_weight=balanced, penalty=l1, solver=saga;, score=0.782 total time=   1.4s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/5] END C=100, class_weight=balanced, penalty=l2, solver=saga;, score=0.784 total time=   1.1s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END C=100, class_weight=balanced, penalty=l2, solver=saga;, score=0.776 total time=   1.0s
# [CV 3/5] END C=100, class_weight=balanced, penalty=l2, solver=saga;, score=0.781 total time=   1.0s
# [CV 4/5] END C=100, class_weight=balanced, penalty=l2, solver=saga;, score=0.774 total time=   1.0s
# /Users/kaustubh/Desktop/ML_Pipeline_Project/env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 5/5] END C=100, class_weight=balanced, penalty=l2, solver=saga;, score=0.782 total time=   1.1s
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'class_weight': ['balanced'], 'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'saga']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 0.001, 'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}

# %%
grid.score(X_train,y_train)
# Out:
# 0.7794767374851128

# %%
y_prad = grid.predict(X_test)

# %%
accuracy_score(y_test,y_prad)
# Out:
# 0.7811923786109404

# %%
dr = DecisionTreeClassifier()

# %%
param_grid = {
    "class_weight":["balanced"],
    "criterion":['gini',"entropy","log_loss"],
    "splitter":['best','random'],
    "max_depth":[3,4,5,6],
    "min_samples_split":[2,3,4,5],
    "min_samples_leaf":[1,2,3],
    "max_features":["auto","sqrt","log2"]
}

# %%
grid_search = GridSearchCV(estimator=dr,param_grid=param_grid,cv=5,scoring="accuracy")

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'class_weight': ['balanced'],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [3, 4, 5, 6],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4, 5],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'splitter': 'best'}

# %%
grid_search.score(X_train,y_train)
# Out:
# 0.7675669445618348

# %%
y_prad = grid_search.predict(X_test)

# %%
accuracy_score(y_test,y_prad)
# Out:
# 0.760141364474493

# %%
print(classification_report(y_test,y_prad))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      4988
#            1       0.49      0.80      0.61      1520
#
#     accuracy                           0.76      6508
#    macro avg       0.71      0.78      0.72      6508
# weighted avg       0.82      0.76      0.78      6508

# %%
rf = RandomForestClassifier()

# %%
param_grid = {
    "class_weight":["balanced"],
    'n_estimators': [20, 50, 30],
    'max_depth': [10, 8, 5],
    'min_samples_split': [2, 5, 10],
}

# %%
grid_search = GridSearchCV(estimator=rf,param_grid=param_grid,cv=5,scoring="accuracy")

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'class_weight': ['balanced'], 'max_depth': [10, 8, 5],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [20, 50, 30]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'class_weight': 'balanced',
#  'max_depth': 10,
#  'min_samples_split': 2,
#  'n_estimators': 30}

# %%
grid_search.score(X_train,y_train)
# Out:
# 0.821929386453571

# %%
y_prad = grid_search.predict(X_test)

# %%
accuracy_score(y_test,y_prad)
# Out:
# 0.8020897357098955

# %%
print(classification_report(y_test,y_prad))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86      4988
#            1       0.55      0.87      0.67      1520
#
#     accuracy                           0.80      6508
#    macro avg       0.75      0.83      0.77      6508
# weighted avg       0.86      0.80      0.81      6508

# %% [markdown]
# # Happy Learning!

# %%
params = {
                "Random Forest":{
                    "class_weight":["balanced"],
                    'n_estimators': [20, 50, 30],
                    'max_depth': [10, 8, 5],
                    'min_samples_split': [2, 5, 10],
                },
                "Decision Tree":{
                    "class_weight":["balanced"],
                    "criterion":['gini',"entropy","log_loss"],
                    "splitter":['best','random'],
                    "max_depth":[3,4,5,6],
                    "min_samples_split":[2,3,4,5],
                    "min_samples_leaf":[1,2,3],
                    "max_features":["auto","sqrt","log2"]
                },
                "Logastic":{
                    "class_weight":["balanced"],
                    'penalty': ['l1', 'l2'],
                    'C': [0.001, 0.01, 0.1, 1, 10, 100],
                    'solver': ['liblinear', 'saga']
                }
            }
